# %% [markdown]
# <a href="https://colab.research.google.com/github/songiangvn/Algorithm-Design/blob/main/AD_Lecture_2_Algorithm_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Motivation Example
#
# Given $f(n) = n^2 + 100n + log_2{n} + 1000$
#
# When n become infinity, what happens with each component?

# %% [markdown]
# # Motivation - Brute force
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Asymptotic order of growth

# %% [markdown]
# ## Big O notation - Upperbound asymptotic
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Cẩn thận nhầm lẫn chỗ này, O(g(n)) thực chất là set of functions

# %% [markdown]
# ### Big O notation: properties
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Big Omega notation - Lowerbound asymptotic

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Quiz Big O Notation & Big Omega Notation

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Big Theta Notation:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Cái theta này là cái complexity đúng tuyệt đối luôn chứ không còn là cận trên cận dưới như O và Omega nữa

# %% [markdown]
# ### Quiz 3:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Một só cái Proposition về cái lim:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Asymptotic bounds for some common functions

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## For Multiple Variable(Chắc cũng k cho tới đây đâu):

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Common running times

# %% [markdown]
# ## Constant time

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Linear time
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Logarithmic time
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Linearithmic time
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Quadratic time
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Cubic time
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Polynomial time
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Exponential time
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Problem

# %% [markdown]
# ## Seach in a sorted rotated array
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Solution & Pseudocode
#
# ![image.png](data:image/png;base64,...)

# %%
arr = [80, 85, 90, 95, 20, 30, 35, 50, 60, 65, 67, 75]
# arr = [1, 2, 3, 4, 5, 6, 7, 8, 9]
# arr = [9, 1, 2, 3, 4, 5, 6, 7, 8]
def find_k(arr):
  '''
  Function này tìm được smallest element trong sorted rotated array(tức là tìm cái điểm hẫng)

  Cách chặt nhị phân mà không cần lưu thêm 1 biến để lưu đáp án:(Với các bài tìm số trong dãy tman tchat)
  +/ Điều kiện kết thúc không còn là l <= r nữa mà sẽ thay đổi thành l < r or l + 2 <= r như code
  +/ Kết quả luôn nằm ở biến hi, so sánh A[mid] với A[hi]
    - Nếu A[mid] tốt hơn A[hi] -> hi = mid(tức là hi luôn dịch theo cái tốt nhất, tốt hơn thì update hi)
    - Ngước lại lo = mid (nếu không thay đổi được tốt hơn thì update lo)
    Ví dụ ở bài này "tốt hơn" : tương đương với nhỏ hơn
  '''
  lo, hi = 0, len(arr) - 1
  while lo + 2 <= hi:
    mid = (lo + hi) // 2
    if arr[mid] < arr[hi]:
      hi = mid
    else:
      lo = mid
  # print(lo, hi)
  return hi

def check_x(arr, x):
  # check if x is in array or not
  lo, hi = 0, len(arr) - 1
  # print(arr)
  while lo + 2 <= hi:
    # print(lo, hi)
    mid = (lo + hi) // 2
    if arr[mid] >= x:
      hi = mid
    else:
      lo = mid
  return arr[hi] == x

k = find_k(arr)
x = 70
print(check_x(arr[:k], x) or check_x(arr[k:], x))
# Out:
# False

# %% [markdown]
# ## 3-SUM
#
# ![image.png](data:image/png;base64,...)

# %%
arr = [-4, -1, 0, 1, 2, 3, 5, 6, 7]
arr.sort()

answer = [] # list of all tuple (i, j, k) that: a[i] + a[j] + a[k] = 0

# 2 pointers with time complexity: O(n^2)
for k in range(2, len(arr)):
  i = 0
  j = k - 1
  while (j > i):
    sum = arr[j] + arr[k]
    while (i < j and arr[i] < -sum):
      i += 1
    if i < j and arr[i] + arr[j] + arr[k] == 0:
      answer.append((arr[i], arr[j], arr[k]))
    j -= 1

print(answer)
# Out:
# [(-1, 0, 1), (-4, 1, 3), (-4, -1, 5)]

# %% [markdown]
# # Quiz

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
